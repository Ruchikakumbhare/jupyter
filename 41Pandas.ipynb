# %%
import pandas as pd

# %%
a=pd.read_excel(r"C:\Users\Rohit\Desktop\jupyterpy\data.xlsx")

# %%
a
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
#loc

# %%
a.loc[0:3 , ['First Name']]
# Out:
#   First Name
# 0      Aarav
# 1     Vihaan
# 2      Ayaan
# 3      Arjun

# %%
a.iloc[0:3 , [0]]       # positional slicing:Selecting rows and columns by integer position
                        # last index excluded
# Out:
#   First Name
# 0      Aarav
# 1     Vihaan
# 2      Ayaan

# %%
a.loc[0]
# Out:
# First Name     Aarav
# Last Name      Patil
# English           85
# Physics           78
# Chemistry         90
# Mathematics       92
# Name: 0, dtype: object

# %%
a.iloc[1]
# Out:
# First Name       Vihaan
# Last Name      Deshmukh
# English              88
# Physics              81
# Chemistry            85
# Mathematics          89
# Name: 1, dtype: object

# %%
# at: Accessing a single value

# %%
a.at[2,'First Name']
# Out:
# 'Ayaan'

# %%
a.at[1:5,'First Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 a.at[1:5,'First Name']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2575, in _AtIndexer.__getitem__(self, key)
#    2572         raise ValueError("Invalid call for scalar access (getting)!")
#    2573     return self.obj.loc[key]
# -> 2575 return super().__getitem__(key)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2527, in _ScalarAccessIndexer.__getitem__(self, key)
#    2524         raise ValueError("Invalid call for scalar access (getting)!")
#    2526 key = self._convert_key(key)
# -> 2527 return self.obj._get_value(*key, takeable=self._takeable)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4221, in DataFrame._get_value(self, index, col, takeable)
#    4215 engine = self.index._engine
#    4217 if not isinstance(self.index, MultiIndex):
# ...

# %%
a.head()
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 0      Aarav     Patil       85       78         90           92
# 1     Vihaan  Deshmukh       88       81         85           89
# 2      Ayaan    Jadhav       90       75         88           84
# 3      Arjun      More       76       89         91           78
# 4    Reyansh     Joshi       82       80         84           85

# %%
# # Rename 
# # Syntax
# 1)Row labelled
#  dataframe_name.rename(index         = {1:"One",               4:"Four"} , inplace= True/False)
#                        For Row         Old value : New value,

# 2)Columns labelled
#  dataframe_name.rename(columns         = {1:"One",               4:"Four"} , inplace= True/False)
#

# %%
a.rename(index={1:'one'},inplace = True)

# %%
a
# Out:
#     First Name Last Name  English  Physics  Chemistry  Mathematics
# 0        Aarav     Patil       85       78         90           92
# one     Vihaan  Deshmukh       88       81         85           89
# 2        Ayaan    Jadhav       90       75         88           84
# 3        Arjun      More       76       89         91           78
# 4      Reyansh     Joshi       82       80         84           85
# ..         ...       ...      ...      ...        ...          ...
# 60       Tarun    Dhumal       82       87         81           85
# 61       Arnav   Khedkar       85       90         78           89
# 62       Payal     Patil       89       76         87           91
# 63       Rahul     Kadam       81       83         84           90
# 64         Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
a.head(1)
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 0      Aarav     Patil       85       78         90           92

# %%
a.head(0)
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, English, Physics, Chemistry, Mathematics]
# Index: []

# %%
a.head(2)
# Out:
#     First Name Last Name  English  Physics  Chemistry  Mathematics
# 0        Aarav     Patil       85       78         90           92
# one     Vihaan  Deshmukh       88       81         85           89

# %%
a.rename(columns = {'English':'Eng'})
# Out:
#     First Name Last Name  Eng  Physics  Chemistry  Mathematics
# 0        Aarav     Patil   85       78         90           92
# one     Vihaan  Deshmukh   88       81         85           89
# 2        Ayaan    Jadhav   90       75         88           84
# 3        Arjun      More   76       89         91           78
# 4      Reyansh     Joshi   82       80         84           85
# ..         ...       ...  ...      ...        ...          ...
# 60       Tarun    Dhumal   82       87         81           85
# 61       Arnav   Khedkar   85       90         78           89
# 62       Payal     Patil   89       76         87           91
# 63       Rahul     Kadam   81       83         84           90
# 64         Jay    Bhagat   90       77         65           88
#
# [65 rows x 6 columns]

# %%
a.loc['one',['First Name','Last Name' , 'English']]
# Out:
# First Name      Vihaan
# Last Name     Deshmukh
# English             88
# Name: one, dtype: object

# %%
a.iloc[3,[0,1,2,3]]
# Out:
# First Name    Arjun
# Last Name      More
# English          76
# Physics          89
# Name: 3, dtype: object

# %%
# Drop
# Syntax

# %%
a
# Out:
#     First Name Last Name  English  Physics  Chemistry  Mathematics
# 0        Aarav     Patil       85       78         90           92
# one     Vihaan  Deshmukh       88       81         85           89
# 2        Ayaan    Jadhav       90       75         88           84
# 3        Arjun      More       76       89         91           78
# 4      Reyansh     Joshi       82       80         84           85
# ..         ...       ...      ...      ...        ...          ...
# 60       Tarun    Dhumal       82       87         81           85
# 61       Arnav   Khedkar       85       90         78           89
# 62       Payal     Patil       89       76         87           91
# 63       Rahul     Kadam       81       83         84           90
# 64         Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
a.drop(['English'] , axis = 1)
# Out:
#     First Name Last Name  Physics  Chemistry  Mathematics
# 0        Aarav     Patil       78         90           92
# one     Vihaan  Deshmukh       81         85           89
# 2        Ayaan    Jadhav       75         88           84
# 3        Arjun      More       89         91           78
# 4      Reyansh     Joshi       80         84           85
# ..         ...       ...      ...        ...          ...
# 60       Tarun    Dhumal       87         81           85
# 61       Arnav   Khedkar       90         78           89
# 62       Payal     Patil       76         87           91
# 63       Rahul     Kadam       83         84           90
# 64         Jay    Bhagat       77         65           88
#
# [65 rows x 5 columns]

# %%
a
# Out:
#     First Name Last Name  English  Physics  Chemistry  Mathematics
# 0        Aarav     Patil       85       78         90           92
# one     Vihaan  Deshmukh       88       81         85           89
# 2        Ayaan    Jadhav       90       75         88           84
# 3        Arjun      More       76       89         91           78
# 4      Reyansh     Joshi       82       80         84           85
# ..         ...       ...      ...      ...        ...          ...
# 60       Tarun    Dhumal       82       87         81           85
# 61       Arnav   Khedkar       85       90         78           89
# 62       Payal     Patil       89       76         87           91
# 63       Rahul     Kadam       81       83         84           90
# 64         Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]
