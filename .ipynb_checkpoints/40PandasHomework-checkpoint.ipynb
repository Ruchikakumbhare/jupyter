# %%
import pandas as pd

# %%
# Read data from sheet "Data"
# Find out student age
# Calculate total marks
# Calculate percentage
# Give top 10 student Roll No, first name, last name, Total marks
# In above data add first name and last name in single column
# Give list of student whoes marks less than 50 in any subject

# %%
x=pd.read_excel(r"C:\Users\Rohit\Desktop\jupyterpy\Homework.xlsx",sheet_name = 'Data')

# %%
x
# Out:
#    Unnamed: 0  Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4   Unnamed: 5  \
# 0         NaN         NaN          NaN        NaN        NaN          NaN
# 1         NaN         NaN          NaN        NaN        NaN          NaN
# 2     Roll No  First Name    Last Name    English   Physics    Chemistry
# 3           1       Aarav        Patil         85         78           90
# 4           2       Aarvi     Bhandari         90         81           85
# 5           3       Aditi       Rajput         90         88           82
# 6           4      Aditya        Pawar         92         88           76
# 7           5       Anaya      Gawande         84         90           82
# 8           6       Arjun         More         76         89           91
# 9           7       Arnav      Khedkar         85         90           78
# 10          8       Ayaan       Jadhav         90         75           88
# 11          9       Disha       Chavan         86         83           80
# ...

# %%
# Read data from sheet "Data"

# %%
x1=pd.read_excel(r"C:\Users\Rohit\Desktop\jupyterpy\Homework.xlsx",sheet_name = 'Data',skiprows=3)

# %%
x1
# Out:
#     Roll No First Name    Last Name  English  Physics    Chemistry   \
# 0         1      Aarav        Patil       85        78           90
# 1         2      Aarvi     Bhandari       90        81           85
# 2         3      Aditi       Rajput       90        88           82
# 3         4     Aditya        Pawar       92        88           76
# 4         5      Anaya      Gawande       84        90           82
# 5         6      Arjun         More       76        89           91
# 6         7      Arnav      Khedkar       85        90           78
# 7         8      Ayaan       Jadhav       90        75           88
# 8         9      Disha       Chavan       86        83           80
# 9        10       Isha       Kamble       79        76           89
# 10       11       Jaya       Bhagat       92        88           76
# 11       12        Jay       Bhagat       90        77           65
# 12       13      Kaira        Nikam       88        80           84
# ...

# %%
# Find out student age

# %%
x1['Age'] = 2024 - x1['DOB Year']

# %%
x1
# Out:
#     Roll No First Name    Last Name  English  Physics    Chemistry   \
# 0         1      Aarav        Patil       85        78           90
# 1         2      Aarvi     Bhandari       90        81           85
# 2         3      Aditi       Rajput       90        88           82
# 3         4     Aditya        Pawar       92        88           76
# 4         5      Anaya      Gawande       84        90           82
# 5         6      Arjun         More       76        89           91
# 6         7      Arnav      Khedkar       85        90           78
# 7         8      Ayaan       Jadhav       90        75           88
# 8         9      Disha       Chavan       86        83           80
# 9        10       Isha       Kamble       79        76           89
# 10       11       Jaya       Bhagat       92        88           76
# 11       12        Jay       Bhagat       90        77           65
# 12       13      Kaira        Nikam       88        80           84
# ...

# %%
# Calculate total marks

# %%
x1['Total Marks'] = x1['English']+x1['Physics']+x1['Chemistry']+x1['Mathematics']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Physics'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ...

# %%
x1.columns
# Out:
# Index(['Roll No', 'First Name', 'Last Name', 'English', 'Physics ',
#        ' Chemistry ', 'Mathematics', 'DOB Year', 'Age'],
#       dtype='object')

# %%
x1['Total Marks'] = x1['English']+x1['Physics ']+x1[' Chemistry ']+x1['Mathematics']

# %%
x1
# Out:
#     Roll No First Name    Last Name  English  Physics    Chemistry   \
# 0         1      Aarav        Patil       85        78           90
# 1         2      Aarvi     Bhandari       90        81           85
# 2         3      Aditi       Rajput       90        88           82
# 3         4     Aditya        Pawar       92        88           76
# 4         5      Anaya      Gawande       84        90           82
# 5         6      Arjun         More       76        89           91
# 6         7      Arnav      Khedkar       85        90           78
# 7         8      Ayaan       Jadhav       90        75           88
# 8         9      Disha       Chavan       86        83           80
# 9        10       Isha       Kamble       79        76           89
# 10       11       Jaya       Bhagat       92        88           76
# 11       12        Jay       Bhagat       90        77           65
# 12       13      Kaira        Nikam       88        80           84
# ...

# %%
# Calculate percentage

# %%
x1['Percentage'] = (x1['Total Marks'] / 400) * 100

# %%
x1
# Out:
#     Roll No First Name    Last Name  English  Physics    Chemistry   \
# 0         1      Aarav        Patil       85        78           90
# 1         2      Aarvi     Bhandari       90        81           85
# 2         3      Aditi       Rajput       90        88           82
# 3         4     Aditya        Pawar       92        88           76
# 4         5      Anaya      Gawande       84        90           82
# 5         6      Arjun         More       76        89           91
# 6         7      Arnav      Khedkar       85        90           78
# 7         8      Ayaan       Jadhav       90        75           88
# 8         9      Disha       Chavan       86        83           80
# 9        10       Isha       Kamble       79        76           89
# 10       11       Jaya       Bhagat       92        88           76
# 11       12        Jay       Bhagat       90        77           65
# 12       13      Kaira        Nikam       88        80           84
# ...

# %%
# Give top 10 student Roll No, first name, last name, Total marks

# %%
x1.sort_values(by = 'Total Marks')
# Out:
#     Roll No First Name    Last Name  English  Physics    Chemistry   \
# 25       26    Samarth       Shinde       43        79           87
# 29       30      Tarun       Dhumal       82        87           44
# 6         7      Arnav      Khedkar       85        90           78
# 19       20     Raghav     Khedekar       79        49           82
# 11       12        Jay       Bhagat       90        77           65
# 28       29      Tanvi       Ingale       78        77           83
# 21       22    Reyansh        Joshi       82        80           84
# 5         6      Arjun         More       76        89           91
# 14       15      Kunal   Kshirsagar       81        81           85
# 24       25      Rohan  Suryavanshi       78        82           90
# 9        10       Isha       Kamble       79        76           89
# 13       14      Krish      Bhosale       80        85           83
# 22       23    Rishabh       Ghadge       92        78           86
# ...

# %%
x1.sort_values(by = 'Total Marks',ascending=False)
# Out:
#     Roll No First Name    Last Name  English  Physics    Chemistry   \
# 27       28      Sneha      Gokhale       88        84           90
# 2         3      Aditi       Rajput       90        88           82
# 3         4     Aditya        Pawar       92        88           76
# 1         2      Aarvi     Bhandari       90        81           85
# 0         1      Aarav        Patil       85        78           90
# 10       11       Jaya       Bhagat       92        88           76
# 4         5      Anaya      Gawande       84        90           82
# 31       32     Vihaan     Deshmukh       88        81           85
# 17       18      Pooja       Mhatre       84        79           88
# 16       17      Payal        Patil       89        76           87
# 12       13      Kaira        Nikam       88        80           84
# 30       31      Tejas     Waghmare       85        82           90
# 26       27     Shreya     Dandekar       89        75           88
# ...

# %%
x1.iloc[0:10,[0,1,2,9]] # top 10 students
# Out:
#    Roll No First Name Last Name  Total Marks
# 0        1      Aarav     Patil          345
# 1        2      Aarvi  Bhandari          347
# 2        3      Aditi    Rajput          347
# 3        4     Aditya     Pawar          347
# 4        5      Anaya   Gawande          344
# 5        6      Arjun      More          334
# 6        7      Arnav   Khedkar          299
# 7        8      Ayaan    Jadhav          337
# 8        9      Disha    Chavan          338
# 9       10       Isha    Kamble          336

# %%
x1.columns
# Out:
# Index(['Roll No', 'First Name', 'Last Name', 'English', 'Physics ',
#        ' Chemistry ', 'Mathematics', 'DOB Year', 'Age', 'Total Marks',
#        'Percentage'],
#       dtype='object')

# %%
# Give list of student whoes marks less than 50 in any subject

# %%
x1[(x1['English'] < 50) | (x1['Physics '] < 50) | (x1[' Chemistry ']<50) | (x1[ 'Mathematics']<50 )]
# Out:
#     Roll No First Name Last Name  English  Physics    Chemistry   Mathematics  \
# 6         7      Arnav   Khedkar       85        90           78           46
# 19       20     Raghav  Khedekar       79        49           82           90
# 25       26    Samarth    Shinde       43        79           87           88
# 29       30      Tarun    Dhumal       82        87           44           85
#
#     DOB Year  Age  Total Marks  Percentage
# 6       2000   24          299       74.75
# 19      1996   28          300       75.00
# 25      2000   24          297       74.25
# 29      2000   24          298       74.50

# %%
# In above data add first name and last name in single column

# %%
x1['Full Name'] = x1['First Name'] + " " +  x1['Last Name']

# %%
x1
# Out:
#     Roll No First Name    Last Name  English  Physics    Chemistry   \
# 0         1      Aarav        Patil       85        78           90
# 1         2      Aarvi     Bhandari       90        81           85
# 2         3      Aditi       Rajput       90        88           82
# 3         4     Aditya        Pawar       92        88           76
# 4         5      Anaya      Gawande       84        90           82
# 5         6      Arjun         More       76        89           91
# 6         7      Arnav      Khedkar       85        90           78
# 7         8      Ayaan       Jadhav       90        75           88
# 8         9      Disha       Chavan       86        83           80
# 9        10       Isha       Kamble       79        76           89
# 10       11       Jaya       Bhagat       92        88           76
# 11       12        Jay       Bhagat       90        77           65
# 12       13      Kaira        Nikam       88        80           84
# ...

# %%
x1.to_excel(r'C:\Users\Rohit\Desktop\jupyterpy\output_files\output1.xlsx')

# %%
x1.to_excel(r'C:\Users\Rohit\Desktop\jupyterpy\output_files\output2.xlsx',index=False) #Index excluded
