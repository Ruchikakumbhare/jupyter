# %%
import pandas as pd

# %%
a=pd.read_excel(r"C:\Users\Rohit\Desktop\jupyterpy\Input data.xlsx")

# %%
a
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
# Accessing columns 
#  using dot - not recommended  # Applicaple whoes satisfies varible name rule
                                # Can not retrive multiple columns
#  using [] : # retrive multiple columns

# %%
a.English
# Out:
# 0     85
# 1     88
# 2     90
# 3     76
# 4     82
#       ..
# 60    82
# 61    85
# 62    89
# 63    81
# 64    90
# Name: English, Length: 65, dtype: int64

# %%
a.First Name
# Out:
#   Cell In[14], line 1
#     a.First Name
#             ^
# SyntaxError: invalid syntax

# %%
a['First Name']
# Out:
# 0       Aarav
# 1      Vihaan
# 2       Ayaan
# 3       Arjun
# 4     Reyansh
#        ...
# 60      Tarun
# 61      Arnav
# 62      Payal
# 63      Rahul
# 64        Jay
# Name: First Name, Length: 65, dtype: object

# %%
a[	'Last Name' ,'First Name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Last Name', 'First Name')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 a[	'Last Name' ,'First Name']
#
# ...

# %%
a[['First Name','Last Name']]
# Out:
#    First Name Last Name
# 0       Aarav     Patil
# 1      Vihaan  Deshmukh
# 2       Ayaan    Jadhav
# 3       Arjun      More
# 4     Reyansh     Joshi
# ..        ...       ...
# 60      Tarun    Dhumal
# 61      Arnav   Khedkar
# 62      Payal     Patil
# 63      Rahul     Kadam
# 64        Jay    Bhagat
#
# [65 rows x 2 columns]

# %%
a
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
a['Physics']
# Out:
# 0     78
# 1     81
# 2     75
# 3     89
# 4     80
#       ..
# 60    87
# 61    90
# 62    76
# 63    83
# 64    77
# Name: Physics, Length: 65, dtype: int64

# %%
a[['Physics'	,'Chemistry']]
# Out:
#     Physics  Chemistry
# 0        78         90
# 1        81         85
# 2        75         88
# 3        89         91
# 4        80         84
# ..      ...        ...
# 60       87         81
# 61       90         78
# 62       76         87
# 63       83         84
# 64       77         65
#
# [65 rows x 2 columns]

# %%
a.head(2)
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics
# 0      Aarav     Patil       85       78         90           92
# 1     Vihaan  Deshmukh       88       81         85           89

# %%
# Create new column

# %%
a
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics Total_Marks
# 0       Aarav     Patil       85       78         90           92       Blank
# 1      Vihaan  Deshmukh       88       81         85           89       Blank
# 2       Ayaan    Jadhav       90       75         88           84       Blank
# 3       Arjun      More       76       89         91           78       Blank
# 4     Reyansh     Joshi       82       80         84           85       Blank
# ..        ...       ...      ...      ...        ...          ...         ...
# 60      Tarun    Dhumal       82       87         81           85       Blank
# 61      Arnav   Khedkar       85       90         78           89       Blank
# 62      Payal     Patil       89       76         87           91       Blank
# 63      Rahul     Kadam       81       83         84           90       Blank
# 64        Jay    Bhagat       90       77         65           88       Blank
#
# [65 rows x 7 columns]

# %%
a['Total_Marks'] = 'Blank'

# %%
a
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics Total_Marks
# 0       Aarav     Patil       85       78         90           92       Blank
# 1      Vihaan  Deshmukh       88       81         85           89       Blank
# 2       Ayaan    Jadhav       90       75         88           84       Blank
# 3       Arjun      More       76       89         91           78       Blank
# 4     Reyansh     Joshi       82       80         84           85       Blank
# ..        ...       ...      ...      ...        ...          ...         ...
# 60      Tarun    Dhumal       82       87         81           85       Blank
# 61      Arnav   Khedkar       85       90         78           89       Blank
# 62      Payal     Patil       89       76         87           91       Blank
# 63      Rahul     Kadam       81       83         84           90       Blank
# 64        Jay    Bhagat       90       77         65           88       Blank
#
# [65 rows x 7 columns]

# %%
a['status'] = 'Blank'

# %%
a
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics Total_Marks  \
# 0       Aarav     Patil       85       78         90           92       Blank
# 1      Vihaan  Deshmukh       88       81         85           89       Blank
# 2       Ayaan    Jadhav       90       75         88           84       Blank
# 3       Arjun      More       76       89         91           78       Blank
# 4     Reyansh     Joshi       82       80         84           85       Blank
# ..        ...       ...      ...      ...        ...          ...         ...
# 60      Tarun    Dhumal       82       87         81           85       Blank
# 61      Arnav   Khedkar       85       90         78           89       Blank
# 62      Payal     Patil       89       76         87           91       Blank
# 63      Rahul     Kadam       81       83         84           90       Blank
# 64        Jay    Bhagat       90       77         65           88       Blank
#
#    status
# 0   Blank
# ...

# %%
a[['First Name',	'Last Name',	'English',	'Physics',	'Chemistry',	'Mathematics',	'Total_Marks',	'status']]
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics Total_Marks  \
# 0       Aarav     Patil       85       78         90           92       Blank
# 1      Vihaan  Deshmukh       88       81         85           89       Blank
# 2       Ayaan    Jadhav       90       75         88           84       Blank
# 3       Arjun      More       76       89         91           78       Blank
# 4     Reyansh     Joshi       82       80         84           85       Blank
# ..        ...       ...      ...      ...        ...          ...         ...
# 60      Tarun    Dhumal       82       87         81           85       Blank
# 61      Arnav   Khedkar       85       90         78           89       Blank
# 62      Payal     Patil       89       76         87           91       Blank
# 63      Rahul     Kadam       81       83         84           90       Blank
# 64        Jay    Bhagat       90       77         65           88       Blank
#
#    status
# 0   Blank
# ...

# %%
a['Total_Marks'] = a['English'] + a['Physics'] + a['Chemistry'] +a['Mathematics']

# %%
a
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#     Total_Marks status
# 0           345  Blank
# 1           343  Blank
# 2           337  Blank
# 3           334  Blank
# 4           331  Blank
# ..          ...    ...
# ...

# %%
a['status'] = 'Done'

# %%
a
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#     Total_Marks status
# 0           345   Done
# 1           343   Done
# 2           337   Done
# 3           334   Done
# 4           331   Done
# ..          ...    ...
# ...

# %%
1+1
# Out:
# 2

# %%
1+'1'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 1+'1'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
'1'+ '2'
# Out:
# '12'

# %%
a['First Name'] =='Payal'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 60    False
# 61    False
# 62     True
# 63    False
# 64    False
# Name: First Name, Length: 65, dtype: bool

# %%
b=pd.read_excel(r'C:\Users\Rohit\Desktop\jupyterpy\Input data.xlsx',sheet_name = 'Sheet2')

# %%
b
# Out:
#   First Name Last Name  English  Physics
# 0        NaN       NaN      NaN      NaN
# 1   ariyansh     gupta     55.0     45.0
# 2     soniya    sharma     66.0     67.0
# 3     preeti     varma     70.0     75.0
# 4       riya   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0
# 6     preeti   gillore     75.0     45.0

# %%
b['First Name'] =='preeti'
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6     True
# Name: First Name, dtype: bool

# %%
b[b['First Name'] =='preeti']
# Out:
#   First Name Last Name  English  Physics
# 3     preeti     varma     70.0     75.0
# 6     preeti   gillore     75.0     45.0

# %%
a[a['First Name'] =='Payal']
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 39      Payal     Patil       89       76         87           91
# 62      Payal     Patil       89       76         87           91
#
#     Total_Marks status
# 39          343   Done
# 62          343   Done

# %%
a
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#     Total_Marks status
# 0           345   Done
# 1           343   Done
# 2           337   Done
# 3           334   Done
# 4           331   Done
# ..          ...    ...
# ...

# %%
len(a)
# Out:
# 65

# %%
b
# Out:
#   First Name Last Name  English  Physics
# 0        NaN       NaN      NaN      NaN
# 1   ariyansh     gupta     55.0     45.0
# 2     soniya    sharma     66.0     67.0
# 3     preeti     varma     70.0     75.0
# 4       riya   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0
# 6     preeti   gillore     75.0     45.0

# %%
b['English'] > 50
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6     True
# Name: English, dtype: bool

# %%
b[b['English'] > 50]
# Out:
#   First Name Last Name  English  Physics
# 1   ariyansh     gupta     55.0     45.0
# 2     soniya    sharma     66.0     67.0
# 3     preeti     varma     70.0     75.0
# 6     preeti   gillore     75.0     45.0

# %%
b[b['English'] <50]
# Out:
#   First Name Last Name  English  Physics
# 4       riya   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0

# %%
b[(b['English'] >=70) & (b['Physics']>=60)]  #&
# Out:
#   First Name Last Name  English  Physics
# 3     preeti     varma     70.0     75.0

# %%
b[(b['English'] >=70) and(b['Physics']>=60)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27352\937804266.py in ?()
# ----> 1 b[(b['English'] >=70) and(b['Physics']>=60)]
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self)
#    1575     @final
#    1576     def __nonzero__(self) -> NoReturn:
# -> 1577         raise ValueError(
#    1578             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1579             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1580         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# Filter data based on condition

# %%
b['Physics'] > 50
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# Name: Physics, dtype: bool

# %%
b['First Name'] = 'sonu'
# Out:
#   First Name Last Name  English  Physics
# 0       sonu       NaN      NaN      NaN
# 1       sonu     gupta     55.0     45.0
# 2       sonu    sharma     66.0     67.0
# 3       sonu     varma     70.0     75.0
# 4       sonu   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0
# 6       sonu   gillore     75.0     45.0

# %%
b
# Out:
#   First Name Last Name  English  Physics
# 0       sonu       NaN      NaN      NaN
# 1       sonu     gupta     55.0     45.0
# 2       sonu    sharma     66.0     67.0
# 3       sonu     varma     70.0     75.0
# 4       sonu   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0
# 6       sonu   gillore     75.0     45.0

# %%
b=pd.read_excel(r'C:\Users\Rohit\Desktop\jupyterpy\Input data.xlsx',sheet_name = 'Sheet2')

# %%
b
# Out:
#   First Name Last Name  English  Physics
# 0        NaN       NaN      NaN      NaN
# 1   ariyansh     gupta     55.0     45.0
# 2     soniya    sharma     66.0     67.0
# 3     preeti     varma     70.0     75.0
# 4       riya   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0
# 6     preeti   gillore     75.0     45.0

# %%
b['First Name'] == 'sonu'
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5     True
# 6    False
# Name: First Name, dtype: bool
