# %%
import pandas as pd

# %%
# Read excel file in pandas
# Syntax
# pd.read_excel("file_path/file_name.extension") ==> Excel
# pd.read_csv("file_path/file_name.csv")  ==> Csv

# %%
# path
# extensions ==> .xlsx = excel file  
                 # .csv= csv file
# single / double slash / raw string

# sheet_name : Specifies which sheet in the Excel file to read. By default read first sheet
# header (None/other number) : Define which row to use as the header (column names).
# usecols : Define which columns to read from the Excel sheet.
# skiprows : Skips a specified number of rows at the start

# %%
x=pd.read_excel("D:\Screenshots\Result1.xlsx")
x
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# <>:1: SyntaxWarning: invalid escape sequence '\S'
# C:\Users\Rohit\AppData\Local\Temp\ipykernel_8176\912615601.py:1: SyntaxWarning: invalid escape sequence '\S'
#   x=pd.read_excel("D:\Screenshots\Result1.xlsx")
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# ...

# %%
pd.read_excel("C:\Users\Rohit\Desktop\jupyterpy\Result1.xlsx")
# Out:
#   Cell In[23], line 1
#     pd.read_excel("C:\Users\Rohit\Desktop\jupyterpy\Result1.xlsx")
#                   ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
pd.read_excel("C:\\Users\\Rohit\\Desktop\\jupyterpy\\tResult1.xlsx")
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
pd.read_excel(r"C:\\Users\\Rohit\\Desktop\\jupyterpy\\tResult1.xlsx")
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
pd.read_excel("C:\\Users\\Rohit\\Desktop\\jupyterpy\\tResult1.xlsx" ,sheet_name = 'S2' )
# Out:
#    Exam No   Student  Sem1  Sem2  Sem3  Sem4
# 0        1  student1    34    40    50    32
# 1        2  student2    45    22    67    55
# 2        3  student3    67    32    44    34
# 3        4  student4    38    42    27    34
# 4        5  student5    56    50    67    44
# 5        6  student6    76    67    56    44

# %%
pd.read_excel("C:\\Users\\Rohit\\Desktop\\jupyterpy\\tResult1.xlsx" ,sheet_name = 'S2',skiprows=[4] )
# Out:
#    Exam No   Student  Sem1  Sem2  Sem3  Sem4
# 0        1  student1    34    40    50    32
# 1        2  student2    45    22    67    55
# 2        3  student3    67    32    44    34
# 3        5  student5    56    50    67    44
# 4        6  student6    76    67    56    44

# %%
pd.read_excel("C:\\Users\\Rohit\\Desktop\\jupyterpy\\tResult1.xlsx" ,sheet_name = 'S2' ,skiprows = [4,5])
# Out:
#    Exam No   Student  Sem1  Sem2  Sem3  Sem4
# 0        1  student1    34    40    50    32
# 1        2  student2    45    22    67    55
# 2        3  student3    67    32    44    34
# 3        6  student6    76    67    56    44

# %%
pd.read_excel("C:\\Users\\Rohit\\Desktop\\jupyterpy\\tResult1.xlsx",usecols=["Exam No","Student","Sem1"])
# Out:
#    Exam No    Student  Sem1
# 0        1   student1    34
# 1        2   student2    45
# 2        3   student3    67
# 3        4   student4    38
# 4        5   student5    56
# 5        6   student6    76
# 6        7   student7    66
# 7        8   student8    45
# 8        9   student9    66
# 9       10  student10    73

# %%
pd.read_excel("C:\\Users\\Rohit\\Desktop\\jupyterpy\\tResult1.xlsx",sheet_name ='S3')
# Out:
#   Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0      Std 5        NaN        NaN        NaN        NaN        NaN
# 1      Div A        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3    Exam No    Student       Sem1       Sem2       Sem3       Sem4
# 4          1   student1         34         40         50         32
# 5          2   student2         45         22         67         55
# 6          3   student3         67         32         44         34
# 7          4   student4         38         42         27         34
# 8          5   student5         56         50         67         44
# 9          6   student6         76         67         56         44

# %%
pd.read_csv(r"C:\Users\Rohit\Desktop\jupyterpy\Resultcsv.csv")
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
a = pd.DataFrame(
    {
        'a' : ['A1','A2','A3'],
        'b' :['B5','B6','B7'],
        'c':['C1','C2','C3']
    },
    index=[1,2,3],
)

# %%
a
# Out:
#     a   b   c
# 1  A1  B5  C1
# 2  A2  B6  C2
# 3  A3  B7  C3

# %%
print(type(a))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# Read csv file in pandas

# %%
pd.read_csv(r"C:\Users\Rohit\Desktop\jupyterpy\Resultcsv.csv")
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
pd.read_csv(r"C:\Users\Rohit\Desktop\jupyterpy\Resultcsv.csv",delimiter = ",")
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
X=pd.read_csv(r"C:\Users\Rohit\Desktop\jupyterpy\Resultcsv.csv",delimiter = ",")

# %%
X
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
# Show starting 5 rows / #rows you mentioned in Parentheses

# %%
X.head()    # Show starting 5 rows / #rows you mentioned in Parentheses
# Out:
#    Exam No   Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1  student1    34    40    50    32   Fail                 37.0
# 1        2  student2    45    22    67    55   Fail                 33.5
# 2        3  student3    67    32    44    34   Fail                 49.5
# 3        4  student4    38    42    27    34   Fail                 40.0
# 4        5  student5    56    50    67    44   Pass                 53.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5

# %%
X.head(6)
# Out:
#    Exam No   Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1  student1    34    40    50    32   Fail                 37.0
# 1        2  student2    45    22    67    55   Fail                 33.5
# 2        3  student3    67    32    44    34   Fail                 49.5
# 3        4  student4    38    42    27    34   Fail                 40.0
# 4        5  student5    56    50    67    44   Pass                 53.0
# 5        6  student6    76    67    56    44   Pass                 71.5
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# 5                 50.0

# %%
 # Show last 5 rows / #rows you mentioned in Parentheses

# %%
X.tail(4)  # Show last 5 rows / #rows you mentioned in Parentheses
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 6                 57.0
# 7                 55.5
# 8                 50.0
# 9                 77.0

# %%
X.tail(2)
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 8                 50.0
# 9                 77.0

# %%
# shape: Returns dimension of the DataFrame in tuple format (rows, columns).

# %%
X.shape
# Out:
# (10, 9)

# %%
X.ndim
# Out:
# 2

# %%
X.dtypes
# Out:
# Exam No                  int64
# Student                 object
# Sem1                     int64
# Sem2                     int64
# Sem3                     int64
# Sem4                     int64
# Result                  object
# 1st Year percentage    float64
# 2nd Year percentage    float64
# dtype: object
