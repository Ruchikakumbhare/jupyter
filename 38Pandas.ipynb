# %%
import pandas as pd

# %%
k=pd.read_excel(r'C:\Users\Rohit\Desktop\jupyterpy\Input data.xlsx',sheet_name = 'Sheet2')

# %%
k
# Out:
#    First Name Last Name  English  Physics
# 0         NaN       NaN      NaN      NaN
# 1    ariyansh     gupta     55.0     45.0
# 2      soniya    sharma     66.0     67.0
# 3      preeti     varma     70.0     75.0
# 4        riya   meshram     45.0     35.0
# 5        sonu    dhurva     40.0     60.0
# 6      preeti   gillore     75.0     45.0
# 7        sonu    dhurva     40.0     60.0
# 8      preeti   gillore     75.0     45.0
# 9        sonu    dhurva     40.0     60.0
# 10     preeti   gillore     75.0     45.0

# %%
# Filter data based on condition

# %%
k['Physics'] >50
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4    False
# 5     True
# 6    False
# Name: Physics, dtype: bool

# %%
k[k['Physics'] >50] # list main print krne se list ajayngi
# Out:
#   First Name Last Name  English  Physics
# 2     soniya    sharma     66.0     67.0
# 3     preeti     varma     70.0     75.0
# 5       sonu    dhurva     40.0     60.0

# %%
k['First Name'] =='riya'
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5    False
# 6    False
# Name: First Name, dtype: bool

# %%
k[k['First Name'] =='riya']
# Out:
#   First Name Last Name  English  Physics
# 4       riya   meshram     45.0     35.0

# %%
k1 = k.copy()

# %%
k1
# Out:
#   First Name Last Name  English  Physics
# 0        NaN       NaN      NaN      NaN
# 1   ariyansh     gupta     55.0     45.0
# 2     soniya    sharma     66.0     67.0
# 3     preeti     varma     70.0     75.0
# 4       riya   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0
# 6     preeti   gillore     75.0     45.0

# %%
k[(k['First Name'] =='sonu') & (k['First Name'] =='riya')]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, English, Physics]
# Index: []

# %%
k[(k['First Name'] =='sonu') | (k['First Name'] =='riya')]
# Out:
#   First Name Last Name  English  Physics
# 4       riya   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0

# %%
k[k['First Name'].isin(['riya' , 'soniya'])]  #if u want two students so used isin method
# Out:
#   First Name Last Name  English  Physics
# 2     soniya    sharma     66.0     67.0
# 4       riya   meshram     45.0     35.0

# %%
k[~k['First Name'].isin(['riya' , 'soniya'])]  # First name except 'riya' , 'soniya'
# Out:
#   First Name Last Name  English  Physics
# 0        NaN       NaN      NaN      NaN
# 1   ariyansh     gupta     55.0     45.0
# 3     preeti     varma     70.0     75.0
# 5       sonu    dhurva     40.0     60.0
# 6     preeti   gillore     75.0     45.0

# %%
k
# Out:
#   First Name Last Name  English  Physics
# 0        NaN       NaN      NaN      NaN
# 1   ariyansh     gupta     55.0     45.0
# 2     soniya    sharma     66.0     67.0
# 3     preeti     varma     70.0     75.0
# 4       riya   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0
# 6     preeti   gillore     75.0     45.0

# %%
# sort_values(by, ascending=True/False): Sorts the DataFrame by the specified column(s).

# %%
k.head(2)
# Out:
#   First Name Last Name  English  Physics
# 0        NaN       NaN      NaN      NaN
# 1   ariyansh     gupta     55.0     45.0

# %%
k
# Out:
#   First Name Last Name  English  Physics
# 0        NaN       NaN      NaN      NaN
# 1   ariyansh     gupta     55.0     45.0
# 2     soniya    sharma     66.0     67.0
# 3     preeti     varma     70.0     75.0
# 4       riya   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0
# 6     preeti   gillore     75.0     45.0

# %%
k1.sort_values(by ='Last Name' , ascending= True)
# Out:
#   First Name Last Name  English  Physics
# 5       sonu    dhurva     40.0     60.0
# 6     preeti   gillore     75.0     45.0
# 1   ariyansh     gupta     55.0     45.0
# 4       riya   meshram     45.0     35.0
# 2     soniya    sharma     66.0     67.0
# 3     preeti     varma     70.0     75.0
# 0        NaN       NaN      NaN      NaN

# %%
k1.sort_values(by ='First Name' , ascending= True,inplace = True)

# %%
k1
# Out:
#   First Name Last Name  English  Physics
# 1   ariyansh     gupta     55.0     45.0
# 3     preeti     varma     70.0     75.0
# 6     preeti   gillore     75.0     45.0
# 4       riya   meshram     45.0     35.0
# 2     soniya    sharma     66.0     67.0
# 5       sonu    dhurva     40.0     60.0
# 0        NaN       NaN      NaN      NaN

# %%
k1.sort_values(by ='First Name' , ascending= False)
# Out:
#   First Name Last Name  English  Physics
# 5       sonu    dhurva     40.0     60.0
# 2     soniya    sharma     66.0     67.0
# 4       riya   meshram     45.0     35.0
# 3     preeti     varma     70.0     75.0
# 6     preeti   gillore     75.0     45.0
# 1   ariyansh     gupta     55.0     45.0
# 0        NaN       NaN      NaN      NaN

# %%
k1
# Out:
#   First Name Last Name  English  Physics
# 0        NaN       NaN      NaN      NaN
# 1   ariyansh     gupta     55.0     45.0
# 2     soniya    sharma     66.0     67.0
# 3     preeti     varma     70.0     75.0
# 4       riya   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0
# 6     preeti   gillore     75.0     45.0

# %%
 # inplace : 
# True==> Change in original dataframe

#False==> Changes not visible in original dataframe

# %%
k1.sort_values(by ='First Name' , ascending= True)  #Change in original dataframe
# Out:
#   First Name Last Name  English  Physics
# 1   ariyansh     gupta     55.0     45.0
# 3     preeti     varma     70.0     75.0
# 6     preeti   gillore     75.0     45.0
# 4       riya   meshram     45.0     35.0
# 2     soniya    sharma     66.0     67.0
# 5       sonu    dhurva     40.0     60.0
# 0        NaN       NaN      NaN      NaN

# %%
k1.sort_values(by ='First Name' , ascending= False)  #Changes not visible in original dataframe
# Out:
#   First Name Last Name  English  Physics
# 5       sonu    dhurva     40.0     60.0
# 2     soniya    sharma     66.0     67.0
# 4       riya   meshram     45.0     35.0
# 3     preeti     varma     70.0     75.0
# 6     preeti   gillore     75.0     45.0
# 1   ariyansh     gupta     55.0     45.0
# 0        NaN       NaN      NaN      NaN

# %%
k1.sort_values(by ='First Name' , ascending= True) .head()
# Out:
#   First Name Last Name  English  Physics
# 1   ariyansh     gupta     55.0     45.0
# 3     preeti     varma     70.0     75.0
# 6     preeti   gillore     75.0     45.0
# 4       riya   meshram     45.0     35.0
# 2     soniya    sharma     66.0     67.0

# %%
len(k1)
# Out:
# 7

# %%
k1
# Out:
#   First Name Last Name  English  Physics
# 1   ariyansh     gupta     55.0     45.0
# 3     preeti     varma     70.0     75.0
# 6     preeti   gillore     75.0     45.0
# 4       riya   meshram     45.0     35.0
# 2     soniya    sharma     66.0     67.0
# 5       sonu    dhurva     40.0     60.0
# 0        NaN       NaN      NaN      NaN

# %%
k1.sort_values(by =['English' , 'Physics'] ,ascending=[False,False],inplace = True)

# %%
k1
# Out:
#   First Name Last Name  English  Physics
# 6     preeti   gillore     75.0     45.0
# 3     preeti     varma     70.0     75.0
# 2     soniya    sharma     66.0     67.0
# 1   ariyansh     gupta     55.0     45.0
# 4       riya   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0
# 0        NaN       NaN      NaN      NaN

# %%
k1.sort_values(by =['Physics' , 'English'] ,ascending=[False,False],inplace = True)

# %%
k1
# Out:
#   First Name Last Name  English  Physics
# 3     preeti     varma     70.0     75.0
# 2     soniya    sharma     66.0     67.0
# 5       sonu    dhurva     40.0     60.0
# 6     preeti   gillore     75.0     45.0
# 1   ariyansh     gupta     55.0     45.0
# 4       riya   meshram     45.0     35.0
# 0        NaN       NaN      NaN      NaN

# %%
# Duplicate

# %%
k1.duplicated()
# Out:
# 3    False
# 2    False
# 5    False
# 6    False
# 1    False
# 4    False
# 0    False
# dtype: bool

# %%
k1[k1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, English, Physics]
# Index: []

# %%
a=pd.read_excel(r'C:\Users\Rohit\Desktop\jupyterpy\Input data.xlsx',sheet_name = 'Sheet2')

# %%
a
# Out:
#    First Name Last Name  English  Physics
# 0         NaN       NaN      NaN      NaN
# 1    ariyansh     gupta     55.0     45.0
# 2      soniya    sharma     66.0     67.0
# 3      preeti     varma     70.0     75.0
# 4        riya   meshram     45.0     35.0
# 5        sonu    dhurva     40.0     60.0
# 6      preeti   gillore     75.0     45.0
# 7        sonu    dhurva     40.0     60.0
# 8      preeti   gillore     75.0     45.0
# 9        sonu    dhurva     40.0     60.0
# 10     preeti   gillore     75.0     45.0

# %%
a.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8      True
# 9      True
# 10     True
# dtype: bool

# %%
a[a.duplicated()]
# Out:
#    First Name Last Name  English  Physics
# 7        sonu    dhurva     40.0     60.0
# 8      preeti   gillore     75.0     45.0
# 9        sonu    dhurva     40.0     60.0
# 10     preeti   gillore     75.0     45.0

# %%
a1=a[a.duplicated(subset = ['First Name','Last Name'])]

# %%
a1
# Out:
#    First Name Last Name  English  Physics
# 7        sonu    dhurva     40.0     60.0
# 8      preeti   gillore     75.0     45.0
# 9        sonu    dhurva     40.0     60.0
# 10     preeti   gillore     75.0     45.0

# %%
a1[(a1['First Name'] =='preeti') &(a1['Last Name'] =='gillore')]
# Out:
#    First Name Last Name  English  Physics
# 8      preeti   gillore     75.0     45.0
# 10     preeti   gillore     75.0     45.0

# %%
a
# Out:
#    First Name Last Name  English  Physics
# 0         NaN       NaN      NaN      NaN
# 1    ariyansh     gupta     55.0     45.0
# 2      soniya    sharma     66.0     67.0
# 3      preeti     varma     70.0     75.0
# 4        riya   meshram     45.0     35.0
# 5        sonu    dhurva     40.0     60.0
# 6      preeti   gillore     75.0     45.0
# 7        sonu    dhurva     40.0     60.0
# 8      preeti   gillore     75.0     45.0
# 9        sonu    dhurva     40.0     60.0
# 10     preeti   gillore     75.0     45.0

# %%
a[a.duplicated(subset =['First Name'])]
# Out:
#    First Name Last Name  English  Physics
# 6      preeti   gillore     75.0     45.0
# 7        sonu    dhurva     40.0     60.0
# 8      preeti   gillore     75.0     45.0
# 9        sonu    dhurva     40.0     60.0
# 10     preeti   gillore     75.0     45.0

# %%
 # Slicing data from the Pandas DataFrame:
 # 1) loc for label-based slicing:Selecting rows and columns using labels # last index included
 # 2) iloc for positional slicing:Selecting rows and columns by integer position # last index excluded
 # 3) at for quick access to single values
 # 4) iat for quick access to single values by position

# %%
a
# Out:
#    First Name Last Name  English  Physics
# 0         NaN       NaN      NaN      NaN
# 1    ariyansh     gupta     55.0     45.0
# 2      soniya    sharma     66.0     67.0
# 3      preeti     varma     70.0     75.0
# 4        riya   meshram     45.0     35.0
# 5        sonu    dhurva     40.0     60.0
# 6      preeti   gillore     75.0     45.0
# 7        sonu    dhurva     40.0     60.0
# 8      preeti   gillore     75.0     45.0
# 9        sonu    dhurva     40.0     60.0
# 10     preeti   gillore     75.0     45.0

# %%
a.loc[1] #Select the first row using label
# Out:
# First Name    ariyansh
# Last Name        gupta
# English           55.0
# Physics           45.0
# Name: 1, dtype: object

# %%
a.loc[0]
# Out:
# First Name    NaN
# Last Name     NaN
# English       NaN
# Physics       NaN
# Name: 0, dtype: object

# %%
a.loc[1:3]  # last index included
# Out:
#   First Name Last Name  English  Physics
# 1   ariyansh     gupta     55.0     45.0
# 2     soniya    sharma     66.0     67.0
# 3     preeti     varma     70.0     75.0

# %%
a.loc[4:6]
# Out:
#   First Name Last Name  English  Physics
# 4       riya   meshram     45.0     35.0
# 5       sonu    dhurva     40.0     60.0
# 6     preeti   gillore     75.0     45.0
