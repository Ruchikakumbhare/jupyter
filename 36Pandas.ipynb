# %%
import pandas as pd

# %%
x=pd.read_excel(r"C:\Users\Rohit\Desktop\jupyterpy\tResult12.xlsx")

# %%
pd.read_excel(r"C:\Users\Rohit\Desktop\jupyterpy\tResult12.xlsx",sheet_name = 'S2')
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4
# 0        1   student1    34    40    50    32
# 1        2   student2    45    22    67    55
# 2        3   student3    67    32    44    34
# 3        4   student4    38    42    27    34
# 4        5   student5    56    50    67    44
# 5        6   student6    76    67    56    44
# 6        7   student7    66    44    76    38
# 7        8   student8    45    27    55    56
# 8        9   student9    66    44    45    55
# 9       10  student10    73    55    66    88

# %%
x
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
x.head()
# Out:
#    Exam No   Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1  student1    34    40    50    32   Fail                 37.0
# 1        2  student2    45    22    67    55   Fail                 33.5
# 2        3  student3    67    32    44    34   Fail                 49.5
# 3        4  student4    38    42    27    34   Fail                 40.0
# 4        5  student5    56    50    67    44   Pass                 53.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5

# %%
x.tail()
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 5                 50.0
# 6                 57.0
# 7                 55.5
# 8                 50.0
# 9                 77.0

# %%
x.head(3)
# Out:
#    Exam No   Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1  student1    34    40    50    32   Fail                 37.0
# 1        2  student2    45    22    67    55   Fail                 33.5
# 2        3  student3    67    32    44    34   Fail                 49.5
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0

# %%
x.tail(1)
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 9                 77.0

# %%
x.shape
# Out:
# (10, 9)

# %%
x.ndim
# Out:
# 2

# %%
x.dtypes
# Out:
# Exam No                  int64
# Student                 object
# Sem1                     int64
# Sem2                     int64
# Sem3                     int64
# Sem4                     int64
# Result                  object
# 1st Year percentage    float64
# 2nd Year percentage    float64
# dtype: object

# %%
x
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
# info(): Provides summary of the DataFrame, including data types and non-null values.

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Exam No              10 non-null     int64
#  1   Student              10 non-null     object
#  2   Sem1                 10 non-null     int64
#  3   Sem2                 10 non-null     int64
#  4   Sem3                 10 non-null     int64
#  5   Sem4                 10 non-null     int64
#  6   Result               10 non-null     object
#  7   1st Year percentage  10 non-null     float64
#  8   2nd Year percentage  10 non-null     float64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 852.0+ bytes

# %%
x1=pd.read_excel(r"C:\Users\Rohit\Desktop\jupyterpy\tResult12.xlsx",sheet_name = 'S5')

# %%
x1
# Out:
# Empty DataFrame
# Columns: [Exam No, Student, Sem1, Sem2, Sem3, Sem4, Result, 1st Year percentage, 2nd Year percentage]
# Index: []

# %%
x1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 0 entries
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Exam No              0 non-null      object
#  1   Student              0 non-null      object
#  2   Sem1                 0 non-null      object
#  3   Sem2                 0 non-null      object
#  4   Sem3                 0 non-null      object
#  5   Sem4                 0 non-null      object
#  6   Result               0 non-null      object
#  7   1st Year percentage  0 non-null      object
#  8   2nd Year percentage  0 non-null      object
# dtypes: object(9)
# memory usage: 132.0+ bytes

# %%
x2=pd.read_excel(r"C:\Users\Rohit\Desktop\jupyterpy\tResult12.xlsx",sheet_name = 'S22')

# %%
x2
# Out:
#     Exam No    Student  Sem1  Sem2  Sem3  Sem4
# 0       1.0   student1  34.0  40.0  50.0  32.0
# 1       2.0   student2  45.0  22.0  67.0  55.0
# 2       3.0   student3  67.0  32.0  44.0  34.0
# 3       NaN        NaN   NaN   NaN   NaN   NaN
# 4       NaN        NaN   NaN   NaN   NaN   NaN
# 5       4.0   student4  38.0  42.0  27.0  34.0
# 6       5.0   student5  56.0  50.0  67.0  44.0
# 7       6.0   student6  76.0  67.0  56.0  44.0
# 8       7.0   student7  66.0  44.0  76.0  38.0
# 9       8.0   student8  45.0  27.0  55.0  56.0
# 10      9.0   student9  66.0  44.0  45.0  55.0
# 11     10.0  student10  73.0  55.0  66.0  88.0

# %%
x2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Exam No  10 non-null     float64
#  1   Student  10 non-null     object
#  2   Sem1     10 non-null     float64
#  3   Sem2     10 non-null     float64
#  4   Sem3     10 non-null     float64
#  5   Sem4     10 non-null     float64
# dtypes: float64(5), object(1)
# memory usage: 708.0+ bytes

# %%
# describe(): Generates descriptive statistics for numerical columns (count, mean, std, min, max, etc.).

# %%
x1
# Out:
# Empty DataFrame
# Columns: [Exam No, Student, Sem1, Sem2, Sem3, Sem4, Result, 1st Year percentage, 2nd Year percentage]
# Index: []

# %%
x1.describe()
# Out:
#        Exam No Student Sem1 Sem2 Sem3 Sem4 Result 1st Year percentage  \
# count        0       0    0    0    0    0      0                   0
# unique       0       0    0    0    0    0      0                   0
# top        NaN     NaN  NaN  NaN  NaN  NaN    NaN                 NaN
# freq       NaN     NaN  NaN  NaN  NaN  NaN    NaN                 NaN
#
#        2nd Year percentage
# count                    0
# unique                   0
# top                    NaN
# freq                   NaN

# %%
x.describe()
# Out:
#         Exam No       Sem1       Sem2       Sem3       Sem4  \
# count  10.00000  10.000000  10.000000  10.000000  10.000000
# mean    5.50000  56.600000  42.300000  55.300000  48.000000
# std     3.02765  15.115849  13.308727  14.453373  16.806084
# min     1.00000  34.000000  22.000000  27.000000  32.000000
# 25%     3.25000  45.000000  34.000000  46.250000  35.000000
# 50%     5.50000  61.000000  43.000000  55.500000  44.000000
# 75%     7.75000  66.750000  48.500000  66.750000  55.000000
# max    10.00000  76.000000  67.000000  76.000000  88.000000
#
#        1st Year percentage  2nd Year percentage
# count            10.000000              10.0000
# mean             49.450000              51.6500
# std              12.700503              12.9723
# min              33.500000              30.5000
# 25%              37.750000              43.2500
# 50%              51.250000              52.7500
# 75%              55.000000              56.6250
# ...

# %%
# size: Total number of elements in the DataFrame

# %%
x
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
x.size
# Out:
# 90

# %%
x2.size
# Out:
# 72

# %%
x2
# Out:
#     Exam No    Student  Sem1  Sem2  Sem3  Sem4
# 0       1.0   student1  34.0  40.0  50.0  32.0
# 1       2.0   student2  45.0  22.0  67.0  55.0
# 2       3.0   student3  67.0  32.0  44.0  34.0
# 3       NaN        NaN   NaN   NaN   NaN   NaN
# 4       NaN        NaN   NaN   NaN   NaN   NaN
# 5       4.0   student4  38.0  42.0  27.0  34.0
# 6       5.0   student5  56.0  50.0  67.0  44.0
# 7       6.0   student6  76.0  67.0  56.0  44.0
# 8       7.0   student7  66.0  44.0  76.0  38.0
# 9       8.0   student8  45.0  27.0  55.0  56.0
# 10      9.0   student9  66.0  44.0  45.0  55.0
# 11     10.0  student10  73.0  55.0  66.0  88.0

# %%
 # index: Returns the index (row labels) of the DataFrame.

# %%
x.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
x2.index
# Out:
# RangeIndex(start=0, stop=12, step=1)

# %%
# empty: Returns True if the DataFrame is empty (no rows), otherwise False.

# %%
x1.empty
# Out:
# True

# %%
x1
# Out:
# Empty DataFrame
# Columns: [Exam No, Student, Sem1, Sem2, Sem3, Sem4, Result, 1st Year percentage, 2nd Year percentage]
# Index: []

# %%
x2.empty
# Out:
# False

# %%
x3=x2.copy()

# %%
x2
# Out:
#     Exam No    Student  Sem1  Sem2  Sem3  Sem4
# 0       1.0   student1  34.0  40.0  50.0  32.0
# 1       2.0   student2  45.0  22.0  67.0  55.0
# 2       3.0   student3  67.0  32.0  44.0  34.0
# 3       NaN        NaN   NaN   NaN   NaN   NaN
# 4       NaN        NaN   NaN   NaN   NaN   NaN
# 5       4.0   student4  38.0  42.0  27.0  34.0
# 6       5.0   student5  56.0  50.0  67.0  44.0
# 7       6.0   student6  76.0  67.0  56.0  44.0
# 8       7.0   student7  66.0  44.0  76.0  38.0
# 9       8.0   student8  45.0  27.0  55.0  56.0
# 10      9.0   student9  66.0  44.0  45.0  55.0
# 11     10.0  student10  73.0  55.0  66.0  88.0

# %%
x3
# Out:
#     Exam No    Student  Sem1  Sem2  Sem3  Sem4
# 0       1.0   student1  34.0  40.0  50.0  32.0
# 1       2.0   student2  45.0  22.0  67.0  55.0
# 2       3.0   student3  67.0  32.0  44.0  34.0
# 3       NaN        NaN   NaN   NaN   NaN   NaN
# 4       NaN        NaN   NaN   NaN   NaN   NaN
# 5       4.0   student4  38.0  42.0  27.0  34.0
# 6       5.0   student5  56.0  50.0  67.0  44.0
# 7       6.0   student6  76.0  67.0  56.0  44.0
# 8       7.0   student7  66.0  44.0  76.0  38.0
# 9       8.0   student8  45.0  27.0  55.0  56.0
# 10      9.0   student9  66.0  44.0  45.0  55.0
# 11     10.0  student10  73.0  55.0  66.0  88.0

# %%
# values: Returns Dataframe as a NumPy array.

# %%
x.values
# Out:
# array([[1, 'student1', 34, 40, 50, 32, 'Fail', 37.0, 41.0],
#        [2, 'student2', 45, 22, 67, 55, 'Fail', 33.5, 61.0],
#        [3, 'student3', 67, 32, 44, 34, 'Fail', 49.5, 39.0],
#        [4, 'student4', 38, 42, 27, 34, 'Fail', 40.0, 30.5],
#        [5, 'student5', 56, 50, 67, 44, 'Pass', 53.0, 55.50000000000001],
#        [6, 'student6', 76, 67, 56, 44, 'Pass', 71.5, 50.0],
#        [7, 'student7', 66, 44, 76, 38, 'Pass', 55.00000000000001,
#         56.99999999999999],
#        [8, 'student8', 45, 27, 55, 56, 'Fail', 36.0, 55.50000000000001],
#        [9, 'student9', 66, 44, 45, 55, 'Pass', 55.00000000000001, 50.0],
#        [10, 'student10', 73, 55, 66, 88, 'Pass', 64.0, 77.0]],
#       dtype=object)

# %%
x3.values
# Out:
# array([[1.0, 'student1', 34.0, 40.0, 50.0, 32.0],
#        [2.0, 'student2', 45.0, 22.0, 67.0, 55.0],
#        [3.0, 'student3', 67.0, 32.0, 44.0, 34.0],
#        [nan, nan, nan, nan, nan, nan],
#        [nan, nan, nan, nan, nan, nan],
#        [4.0, 'student4', 38.0, 42.0, 27.0, 34.0],
#        [5.0, 'student5', 56.0, 50.0, 67.0, 44.0],
#        [6.0, 'student6', 76.0, 67.0, 56.0, 44.0],
#        [7.0, 'student7', 66.0, 44.0, 76.0, 38.0],
#        [8.0, 'student8', 45.0, 27.0, 55.0, 56.0],
#        [9.0, 'student9', 66.0, 44.0, 45.0, 55.0],
#        [10.0, 'student10', 73.0, 55.0, 66.0, 88.0]], dtype=object)

# %%
# columns: Returns the column names of the DataFrame.

# %%
x
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
x.columns
# Out:
# Index(['Exam No', 'Student', 'Sem1', 'Sem2', 'Sem3', 'Sem4', 'Result',
#        '1st Year percentage', '2nd Year percentage'],
#       dtype='object')

# %%
 # Transpose :Transposes the DataFrame, swapping rows and columns

# %%
x.T
# Out:
#                             0         1         2         3         4  \
# Exam No                     1         2         3         4         5
# Student              student1  student2  student3  student4  student5
# Sem1                       34        45        67        38        56
# Sem2                       40        22        32        42        50
# Sem3                       50        67        44        27        67
# Sem4                       32        55        34        34        44
# Result                   Fail      Fail      Fail      Fail      Pass
# 1st Year percentage      37.0      33.5      49.5      40.0      53.0
# 2nd Year percentage      41.0      61.0      39.0      30.5      55.5
#
#                             5         6         7         8          9
# Exam No                     6         7         8         9         10
# Student              student6  student7  student8  student9  student10
# ...

# %%
x.transpose()
# Out:
#                             0         1         2         3         4  \
# Exam No                     1         2         3         4         5
# Student              student1  student2  student3  student4  student5
# Sem1                       34        45        67        38        56
# Sem2                       40        22        32        42        50
# Sem3                       50        67        44        27        67
# Sem4                       32        55        34        34        44
# Result                   Fail      Fail      Fail      Fail      Pass
# 1st Year percentage      37.0      33.5      49.5      40.0      53.0
# 2nd Year percentage      41.0      61.0      39.0      30.5      55.5
#
#                             5         6         7         8          9
# Exam No                     6         7         8         9         10
# Student              student6  student7  student8  student9  student10
# ...

# %%
x2
# Out:
#     Exam No    Student  Sem1  Sem2  Sem3  Sem4
# 0       1.0   student1  34.0  40.0  50.0  32.0
# 1       2.0   student2  45.0  22.0  67.0  55.0
# 2       3.0   student3  67.0  32.0  44.0  34.0
# 3       NaN        NaN   NaN   NaN   NaN   NaN
# 4       NaN        NaN   NaN   NaN   NaN   NaN
# 5       4.0   student4  38.0  42.0  27.0  34.0
# 6       5.0   student5  56.0  50.0  67.0  44.0
# 7       6.0   student6  76.0  67.0  56.0  44.0
# 8       7.0   student7  66.0  44.0  76.0  38.0
# 9       8.0   student8  45.0  27.0  55.0  56.0
# 10      9.0   student9  66.0  44.0  45.0  55.0
# 11     10.0  student10  73.0  55.0  66.0  88.0

# %%
x2.T
# Out:
#                0         1         2    3    4         5         6         7   \
# Exam No       1.0       2.0       3.0  NaN  NaN       4.0       5.0       6.0
# Student  student1  student2  student3  NaN  NaN  student4  student5  student6
# Sem1         34.0      45.0      67.0  NaN  NaN      38.0      56.0      76.0
# Sem2         40.0      22.0      32.0  NaN  NaN      42.0      50.0      67.0
# Sem3         50.0      67.0      44.0  NaN  NaN      27.0      67.0      56.0
# Sem4         32.0      55.0      34.0  NaN  NaN      34.0      44.0      44.0
#
#                8         9         10         11
# Exam No       7.0       8.0       9.0       10.0
# Student  student7  student8  student9  student10
# Sem1         66.0      45.0      66.0       73.0
# Sem2         44.0      27.0      44.0       55.0
# Sem3         76.0      55.0      45.0       66.0
# Sem4         38.0      56.0      55.0       88.0

# %%
# Accessing columns 
#  using dot - not recommended 
#  using [] :

# %%
x2
# Out:
#     Exam No    Student  Sem1  Sem2  Sem3  Sem4
# 0       1.0   student1  34.0  40.0  50.0  32.0
# 1       2.0   student2  45.0  22.0  67.0  55.0
# 2       3.0   student3  67.0  32.0  44.0  34.0
# 3       NaN        NaN   NaN   NaN   NaN   NaN
# 4       NaN        NaN   NaN   NaN   NaN   NaN
# 5       4.0   student4  38.0  42.0  27.0  34.0
# 6       5.0   student5  56.0  50.0  67.0  44.0
# 7       6.0   student6  76.0  67.0  56.0  44.0
# 8       7.0   student7  66.0  44.0  76.0  38.0
# 9       8.0   student8  45.0  27.0  55.0  56.0
# 10      9.0   student9  66.0  44.0  45.0  55.0
# 11     10.0  student10  73.0  55.0  66.0  88.0

# %%
x2.Student
# Out:
# 0      student1
# 1      student2
# 2      student3
# 3           NaN
# 4           NaN
# 5      student4
# 6      student5
# 7      student6
# 8      student7
# 9      student8
# 10     student9
# 11    student10
# Name: Student, dtype: object

# %%
x2.Sem4
# Out:
# 0     32.0
# 1     55.0
# 2     34.0
# 3      NaN
# 4      NaN
# 5     34.0
# 6     44.0
# 7     44.0
# 8     38.0
# 9     56.0
# 10    55.0
# 11    88.0
# Name: Sem4, dtype: float64

# %%
x2.Exam No
# Out:
#   Cell In[109], line 1
#     x2.Exam No
#             ^
# SyntaxError: invalid syntax
