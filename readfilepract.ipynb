# %%
import pandas as pd

# %%
q=pd.read_excel(r"C:\Users\Rohit\Desktop\jupyterpy\data.xlsx")

# %%
q
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
q.columns
# Out:
# Index(['First Name', 'Last Name', 'English', 'Physics', 'Chemistry',
#        'Mathematics'],
#       dtype='object')

# %%
q['Total Marks'] = q['English']+q['Physics']+q['Chemistry']+q['Mathematics']

# %%
q
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total Marks
# 0       Aarav     Patil       85       78         90           92          345
# 1      Vihaan  Deshmukh       88       81         85           89          343
# 2       Ayaan    Jadhav       90       75         88           84          337
# 3       Arjun      More       76       89         91           78          334
# 4     Reyansh     Joshi       82       80         84           85          331
# ..        ...       ...      ...      ...        ...          ...          ...
# 60      Tarun    Dhumal       82       87         81           85          335
# 61      Arnav   Khedkar       85       90         78           89          342
# 62      Payal     Patil       89       76         87           91          343
# 63      Rahul     Kadam       81       83         84           90          338
# 64        Jay    Bhagat       90       77         65           88          320
#
# [65 rows x 7 columns]

# %%
q['Full Name'] = q['First Name'] + "  " +q['Last Name']

# %%
q
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#     Total Marks         Full Name
# 0           345      Aarav  Patil
# 1           343  Vihaan  Deshmukh
# 2           337     Ayaan  Jadhav
# ...

# %%
q.drop('First Name', axis = 1)
# Out:
#    Last Name  English  Physics  Chemistry  Mathematics  Total Marks  \
# 0      Patil       85       78         90           92          345
# 1   Deshmukh       88       81         85           89          343
# 2     Jadhav       90       75         88           84          337
# 3       More       76       89         91           78          334
# 4      Joshi       82       80         84           85          331
# ..       ...      ...      ...        ...          ...          ...
# 60    Dhumal       82       87         81           85          335
# 61   Khedkar       85       90         78           89          342
# 62     Patil       89       76         87           91          343
# 63     Kadam       81       83         84           90          338
# 64    Bhagat       90       77         65           88          320
#
#            Full Name
# 0       Aarav  Patil
# 1   Vihaan  Deshmukh
# 2      Ayaan  Jadhav
# 3        Arjun  More
# 4     Reyansh  Joshi
# ...

# %%
q
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  \
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
#     Total Marks         Full Name
# 0           345      Aarav  Patil
# 1           343  Vihaan  Deshmukh
# 2           337     Ayaan  Jadhav
# ...

# %%
q.drop('First Name', axis = 1 , inplace = True)

# %%
q
# Out:
#    Last Name  English  Physics  Chemistry  Mathematics  Total Marks  \
# 0      Patil       85       78         90           92          345
# 1   Deshmukh       88       81         85           89          343
# 2     Jadhav       90       75         88           84          337
# 3       More       76       89         91           78          334
# 4      Joshi       82       80         84           85          331
# ..       ...      ...      ...        ...          ...          ...
# 60    Dhumal       82       87         81           85          335
# 61   Khedkar       85       90         78           89          342
# 62     Patil       89       76         87           91          343
# 63     Kadam       81       83         84           90          338
# 64    Bhagat       90       77         65           88          320
#
#            Full Name
# 0       Aarav  Patil
# 1   Vihaan  Deshmukh
# 2      Ayaan  Jadhav
# 3        Arjun  More
# 4     Reyansh  Joshi
# ...

# %%
q.drop('Last Name', axis = 1 , inplace = True)

# %%
q
# Out:
#     English  Physics  Chemistry  Mathematics  Total Marks         Full Name
# 0        85       78         90           92          345      Aarav  Patil
# 1        88       81         85           89          343  Vihaan  Deshmukh
# 2        90       75         88           84          337     Ayaan  Jadhav
# 3        76       89         91           78          334       Arjun  More
# 4        82       80         84           85          331    Reyansh  Joshi
# ..      ...      ...        ...          ...          ...               ...
# 60       82       87         81           85          335     Tarun  Dhumal
# 61       85       90         78           89          342    Arnav  Khedkar
# 62       89       76         87           91          343      Payal  Patil
# 63       81       83         84           90          338      Rahul  Kadam
# 64       90       77         65           88          320       Jay  Bhagat
#
# [65 rows x 6 columns]

# %%
q.columns
# Out:
# Index(['English', 'Physics', 'Chemistry', 'Mathematics', 'Total Marks',
#        'Full Name'],
#       dtype='object')

# %%
q[['Full Name','English', 'Physics', 'Chemistry', 'Mathematics', 'Total Marks' ]]
# Out:
#            Full Name  English  Physics  Chemistry  Mathematics  Total Marks
# 0       Aarav  Patil       85       78         90           92          345
# 1   Vihaan  Deshmukh       88       81         85           89          343
# 2      Ayaan  Jadhav       90       75         88           84          337
# 3        Arjun  More       76       89         91           78          334
# 4     Reyansh  Joshi       82       80         84           85          331
# ..               ...      ...      ...        ...          ...          ...
# 60     Tarun  Dhumal       82       87         81           85          335
# 61    Arnav  Khedkar       85       90         78           89          342
# 62      Payal  Patil       89       76         87           91          343
# 63      Rahul  Kadam       81       83         84           90          338
# 64       Jay  Bhagat       90       77         65           88          320
#
# [65 rows x 6 columns]

# %%
q['Percentage'] = (q['Total Marks'] / 400)*100

# %%
q
# Out:
#     English  Physics  Chemistry  Mathematics  Total Marks         Full Name  \
# 0        85       78         90           92          345      Aarav  Patil
# 1        88       81         85           89          343  Vihaan  Deshmukh
# 2        90       75         88           84          337     Ayaan  Jadhav
# 3        76       89         91           78          334       Arjun  More
# 4        82       80         84           85          331    Reyansh  Joshi
# ..      ...      ...        ...          ...          ...               ...
# 60       82       87         81           85          335     Tarun  Dhumal
# 61       85       90         78           89          342    Arnav  Khedkar
# 62       89       76         87           91          343      Payal  Patil
# 63       81       83         84           90          338      Rahul  Kadam
# 64       90       77         65           88          320       Jay  Bhagat
#
#     Percentage
# 0        86.25
# 1        85.75
# ...

# %%
q[['Full Name','English', 'Physics', 'Chemistry', 'Mathematics', 'Total Marks','Percentage' ]]
# Out:
#            Full Name  English  Physics  Chemistry  Mathematics  Total Marks  \
# 0       Aarav  Patil       85       78         90           92          345
# 1   Vihaan  Deshmukh       88       81         85           89          343
# 2      Ayaan  Jadhav       90       75         88           84          337
# 3        Arjun  More       76       89         91           78          334
# 4     Reyansh  Joshi       82       80         84           85          331
# ..               ...      ...      ...        ...          ...          ...
# 60     Tarun  Dhumal       82       87         81           85          335
# 61    Arnav  Khedkar       85       90         78           89          342
# 62      Payal  Patil       89       76         87           91          343
# 63      Rahul  Kadam       81       83         84           90          338
# 64       Jay  Bhagat       90       77         65           88          320
#
#     Percentage
# 0        86.25
# 1        85.75
# ...
